# %% [markdown]
# <img style="float: center;" src='https://github.com/STScI-MIRI/MRS-ExampleNB/raw/main/assets/banner1.png' alt="stsci_logo" width="900px"/>

# %% [markdown]
# <a id="title_ID"></a>
# # MIRI MRS Batch Processing Notebook #

# %% [markdown]
# **Author**: David Law (AURA Associate Astronomer, MIRI branch), Kirsten Larson (ESA/AURA Astronomer, MIRI branch)
# <br>
# **Last Updated**: January 31, 2024
# <br>
# **Pipeline Version**: 1.13.4

# %% [markdown]
# The purpose of this notebook is to provide a framework for processing generic MIRI MRS data through all three pipeline stages.  Data is assumed to be located in two Observation folders (science and background) according to paths set up below.  It should not be necessary to edit any cells other than in the 'Configuration' section unless modifying the standard pipeline processing for MIRI MRS.
#
# This example is set up to use observations of the LMC planetary nebula SMP LMC 058 obtained by PID 1523 Observation 3.  This is a point source that uses a standard 4-pt dither in all three grating settings.  It incorporates a dedicated background in Observation 4.  Input data for this notebook can be obtained by downloading the 'uncal' files from MAST and placing them in directories set up below.
#
# This notebook is regularly updated as improvements are made to the pipeline. Find the most up to date version of this notebook at:
# https://github.com/STScI-MIRI/MRS-ExampleNB/blob/main/Flight_Notebook1/MRS_FlightNB1.ipynb
#
#
# Changes:<br>
# Sep 1 2022: Add some commentary and example on how to use multicore processing in Detector 1<br>
# Sep 12 2022: Disable unnecessary cube/1d spectra production for individual science exposures in Spec 2<br>
# Oct 14 2022: Include residual fringe correction in spec2 (note that this will CRASH earlier pipeline versions!<br>
# Jun 29 2023: Update to latest 1.11.0 pipeline with photom, outlier detection, and x1d changes, add CRDS path options.  Change to SMP LMC 058 demo.<br>
# Oct 11 2023: Update to 1.12.3 pipeline with 1d spectral residual fringe and auto-centroid options, 2d pixel replacement, and a variety of new cube build options.<br>
# Nov 17 2023: Incorporate CRDS default parameters for detector1 and spec2<br>
# Nov 20 2023: Significant revisions to allow use of associations in spec2, allow choice of pixel-based background subtraction.<br>
# Nov 24 2023: Additional comments and plotting examples.<br>
# Jan 31 2024: Update to 1.13.4 pipeline, enabling spectral leak correction

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 1.<font color='white'>-</font>Configuration <a class="anchor" id="intro"></a>
# ------------------

# %%
# Set parameters to be changed here.
# It should not be necessary to edit cells below this in general unless modifying pipeline processing steps.

import sys,os, pdb

# -----------------------------    Set CRDS context and paths   ----------------------------
# CRDS context (if overriding)

# %env CRDS_CONTEXT  jwst_1188.pmap 

# Set CRDS paths if not set already in your .bashrc shell configuration
os.environ['CRDS_PATH'] = "/home/ev-linux/JWST-3D/cdrs_cache"   #use this path for Workshop

os.environ['CRDS_SERVER_URL']='https://jwst-crds.stsci.edu'
# Echo CRDS path in use
print('CRDS local filepath:',os.environ['CRDS_PATH'])
print('CRDS file server:',os.environ['CRDS_SERVER_URL'])

# -----------------------------    Set Directories   ----------------------------

# Point to where the uncalibrated FITS files are from the science observation
input_dir = '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input/'

# Point to where you want the output science results to go
output_dir = '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/'

# Point to where the uncalibrated FITS files are from the background observation
# If no background observation, leave this blank
input_bgdir = '' #'/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/bkg_input/'

# Point to where the output background observations should go
# If no background observation, leave this blank
output_bgdir = '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/bkg_out/'

# -----------------------------    Set Processing Steps   ----------------------------

# -----------------------------    Set Processing Steps   ----------------------------

# Whether or not to process only data from a given band/channel
# Useful if overriding reference files
# Note BOTH must be set in order to work
use_ch='34' # '12' or '34'
use_band='SHORT' # 'SHORT', 'MEDIUM', or 'LONG'


# Whether or not to run a given pipeline stage:

# Science processing
dodet1=True
dospec2=True
dospec3=True

# Background processing
dodet1bg=True
dospec2bg=True #needed for Master Background subtraction

# Where should background subtraction using the dedicated backgrounds be done?
# (Note that if using master-background subtraction, backgrounds must be select above to process through spec2)
pixel_bg = True # Pixel-based background subtraction in spec2 (direct pixel subtraction) -Deep background exposures needed to not add noise.
master_bg = True # Master-background subtraction in spec3 (subtract spectrum generated from the backgrounds) -This is the default pipeline setting

# (If none of the above is done, cubes will not be background subtracted.  1d spectra will use local annular background subtraction for point sources)

# If there is no background folder, ensure we don't try to process it
if (input_bgdir == ''):
    dodet1bg=False
    dospec2bg=False
# Out:
# env: CRDS_CONTEXT=jwst_1188.pmap
# CRDS local filepath: /home/ev-linux/JWST-3D/cdrs_cache
# CRDS file server: https://jwst-crds.stsci.edu

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 2.<font color='white'>-</font>Imports and setup <a class="anchor" id="intro"></a>
# ------------------

# %%
# Now let's use the entire available screen width for the notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# Basic system utilities for interacting with files
#----------------------------------------------General Imports-----------------------------------------------------
import glob
import time
import shutil
import warnings
import zipfile
import urllib.request
# Numpy for doing calculations
import numpy as np

#--------------------------------------------Astropy Imports--------------------------------------------
# Astropy utilities for opening FITS and ASCII files
from astropy.io import fits
from astropy.io import ascii
from astropy.utils.data import download_file
# Astropy utilities for making plots
from astropy.visualization import (LinearStretch, LogStretch, ImageNormalize, ZScaleInterval)

#------------------------------------------------Plotting Imports--------------------------------------------------
# Matplotlib for making plots
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
#--------------------------------------JWST Calibration Pipeline Imports-------------------------------------------
# Import the base JWST package
import jwst
import crds


# JWST pipelines (encompassing many steps)
from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Spec2Pipeline
from jwst.pipeline import Spec3Pipeline
#from jwst.extract_1d import Extract1dStep     #Extract1D Individual Step

# JWST pipeline utilities
from jwst import datamodels # JWST datamodels
from jwst.associations import asn_from_list as afl # Tools for creating association files
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase # Definition of a Lvl2 association file
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base # Definition of a Lvl3 association file

from stcal import dqflags # Utilities for working with the data quality (DQ) arrays


#--
print("JWST Calibration Pipeline Version={}".format(jwst.__version__))
print("Current Operational CRDS Context = {}".format(crds.get_default_context()))
# Out:
# 2024-02-21 02:37:24,964 - stpipe - WARNING - /tmp/ipykernel_1290465/4101078115.py:19: DeprecationWarning: dqflags has been moved to stdatamodels.dqflags, please use that instead
#   from stcal import dqflags # Utilities for working with the data quality (DQ) arrays
# JWST Calibration Pipeline Version=1.13.4
# Current Operational CRDS Context = jwst_1197.pmap

# %%
# Output subdirectories to keep science data products organized
# Note that the pipeline might complain about this as it is intended to work with everything in a single
# directory, but it nonetheless works fine for the examples given here.
det1_dir = os.path.join(output_dir, 'stage1/') # Detector1 pipeline outputs will go here
spec2_dir = os.path.join(output_dir, 'stage2/') # Spec2 pipeline outputs will go here
spec3_dir = os.path.join(output_dir, 'stage3/') # Spec3 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(spec2_dir):
    os.makedirs(spec2_dir)
if not os.path.exists(spec3_dir):
    os.makedirs(spec3_dir)

# %%
# Output subdirectories to keep background data products organized
det1_bgdir = os.path.join(output_bgdir, 'stage1/') # Detector1 pipeline outputs will go here
spec2_bgdir = os.path.join(output_bgdir, 'stage2/') # Spec2 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if (output_bgdir != ''):
    if not os.path.exists(det1_bgdir):
        os.makedirs(det1_bgdir)
    if not os.path.exists(spec2_bgdir):
        os.makedirs(spec2_bgdir)

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 3.<font color='white'>-</font>Detector1 Pipeline <a class="anchor" id="det1"></a>
# ------------------
#
# <div class="alert alert-block alert-warning">
# In this section we process our data through the Detector1 pipeline to create Lvl2a data products (i.e., uncalibrated slope images).
#
# See https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_detector1.html
# </div>

# %%
# First we'll define a function that will call the detector1 pipeline with our desired set of parameters
# We won't enumerate the individual steps
def rundet1(filename, outdir):
    print(filename)
    # Set default configuration from CRDS param reference files
    # -This is required when running the pipeline in a function.
    crds_config = Detector1Pipeline.get_config_from_reference(filename)
    det1 = Detector1Pipeline.from_config_section(crds_config)
    
    det1.output_dir = outdir # Specify where the output should go
    
    # Overrides for whether or not certain steps should be skipped
    #det1.dq_init.skip = False
    #det1.saturation.skip = False
    #det1.firstframe.skip = False
    #det1.lastframe.skip = False
    #det1.reset.skip = False
    #det1.linearity.skip = False
    #det1.rscd.skip = False
    #det1.dark_current.skip = False
    #det1.refpix.skip = False
    #det1.jump.skip = False
    #det1.ramp_fit.skip = False
    #det1.gain_scale.skip = False
    
    # The jump and ramp fitting steps can benefit from multi-core processing, but this is off by default
    # Turn them on here if desired by choosing how many cores to use (quarter, half, or all)
    det1.jump.maximum_cores='half'
    det1.ramp_fit.maximum_cores='half'
    # This next parameter helps with very bright objects and/or very short ramps
    det1.jump.three_group_rejection_threshold=100
    
    # Enable detection of large cosmic ray showers (currently only works for FASTR1 data)
    det1.jump.find_showers=True
    
    # Bad pixel mask overrides
    #det1.dq_init.override_mask = 'myfile.fits'

    # Saturation overrides
    #et1.saturation.override_saturation = 'myfile.fits'
    
    # Reset overrides
    #det1.reset.override_reset = 'myfile.fits'
        
    # Linearity overrides
    #det1.linearity.override_linearity = 'myfile.fits'

    # RSCD overrides
    #det1.rscd.override_rscd = 'myfile.fits'
        
    # DARK overrides
    #det1.dark_current.override_dark = 'myfile.fits'
        
    # GAIN overrides
    #det1.jump.override_gain = 'myfile.fits'
    #det1.ramp_fit.override_gain = 'myfile.fits'
                
    # READNOISE overrides
    #det1.jump.override_readnoise = 'myfile.fits'
    #det1.ramp_fit.override_readnoise = 'myfile.fits'
        
    det1.save_results = True # Save the final resulting _rate.fits files
    det1(filename) # Run the pipeline on an input list of files

# %%
# Now let's look for input files of the form *uncal.fits from the science observation
sstring = input_dir + 'jw*mirifu*uncal.fits'
lvl1b_files = np.array(sorted(glob.glob(sstring)))

# If desired, check that these are the band/channel to use
if ((use_ch != '')&(use_band != '')):
    keep=np.zeros(len(lvl1b_files))
    for ii in range(0,len(lvl1b_files)):
        hdu=fits.open(lvl1b_files[ii])
        hdr=hdu[0].header
        if ((hdr['CHANNEL'] == use_ch)&(hdr['BAND'] == use_band)):
            keep[ii]=1
        hdu.close()
    indx=np.where(keep == 1)
    lvl1b_files=lvl1b_files[indx]

print('Found ' + str(len(lvl1b_files)) + ' science input files')
# Out:
# Found 4 science input files

# %%
# Run the pipeline on these input files by a simple loop over our pipeline function
if dodet1:
    for file in lvl1b_files:
        rundet1(file, det1_dir)
else:
    print('Skipping Detector1 processing for SCI data')
# Out:
# /home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input/jw01640011001_04101_00001_mirifulong_uncal.fits
# 2024-02-21 02:37:26,603 - CRDS - ERROR -  Error determining best reference for 'pars-emicorrstep'  =   Unknown reference type 'pars-emicorrstep'
# 2024-02-21 02:37:26,616 - CRDS - ERROR -  Error determining best reference for 'pars-jumpstep'  =    parameter='META.INSTRUMENT.DETECTOR [DETECTOR]' value='MIRIFULONG' is not in ['MIRIMAGE']
# 2024-02-21 02:37:26,618 - stpipe - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_pars-detector1pipeline_0001.asdf
# 2024-02-21 02:37:26,629 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2024-02-21 02:37:26,630 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2024-02-21 02:37:26,631 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2024-02-21 02:37:26,632 - stpipe.Detector1Pipeline.emicorr - INFO - EmiCorrStep instance created.
# 2024-02-21 02:37:26,633 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2024-02-21 02:37:26,633 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2024-02-21 02:37:26,634 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2024-02-21 02:37:26,635 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2024-02-21 02:37:26,635 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2024-02-21 02:37:26,636 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2024-02-21 02:37:26,637 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2024-02-21 02:37:26,637 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2024-02-21 02:37:26,638 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2024-02-21 02:37:26,639 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2024-02-21 02:37:26,639 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2024-02-21 02:37:26,640 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2024-02-21 02:37:26,641 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2024-02-21 02:37:26,642 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2024-02-21 02:37:26,643 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2024-02-21 02:37:26,710 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input/jw01640011001_04101_00001_mirifulong_uncal.fits',).
# 2024-02-21 02:37:26,716 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'emicorr': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_intermediate_results': False, 'user_supplied_reffile': None, 'nints_to_phase': None, 'nbins': None, 'scale_reference': True}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hook ...
# 2024-02-21 02:37:26,932 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01640011001_04101_00001_mirifulong_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2024-02-21 02:37:26,944 - CRDS - INFO -  Fetching  /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_linearity_0033.fits   21.2 M bytes  (1 / 1 files) (0 / 21.2 M bytes)
# 2024-02-21 02:37:28,465 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_dark_0093.fits'.
# 2024-02-21 02:37:28,466 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_gain_0006.fits'.
# 2024-02-21 02:37:28,466 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_linearity_0033.fits'.
# 2024-02-21 02:37:28,467 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_mask_0054.fits'.
# 2024-02-21 02:37:28,467 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2024-02-21 02:37:28,468 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_readnoise_0086.fits'.
# 2024-02-21 02:37:28,468 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2024-02-21 02:37:28,468 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_reset_0079.fits'.
# 2024-02-21 02:37:28,469 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_rscd_0016.fits'.
# 2024-02-21 02:37:28,469 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_saturation_0035.fits'.
# 2024-02-21 02:37:28,469 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2024-02-21 02:37:28,469 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2024-02-21 02:37:28,470 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2024-02-21 02:37:28,471 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2024-02-21 02:37:28,911 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:28,912 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:37:29,122 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2024-02-21 02:37:29,123 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2024-02-21 02:37:29,125 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2024-02-21 02:37:29,203 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:29,204 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:37:29,218 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_mask_0054.fits
# 2024-02-21 02:37:29,236 - stpipe.Detector1Pipeline.dq_init - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/stdatamodels/validate.py:38: ValidationWarning: While validating meta.exposure.ngroups the following error occurred:
# 'BETWEEN 0 50' is not of type 'integer'
#
# Failed validating 'type' in schema:
#     OrderedDict([('title', 'Number of groups in integration'),
#                  ('type', 'integer'),
#                  ('fits_keyword', 'NGROUPS')])
#
# On instance:
#     'BETWEEN 0 50'
#   warnings.warn(errmsg, ValidationWarning)
#
# 2024-02-21 02:37:29,473 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2024-02-21 02:37:29,553 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:29,554 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'save_intermediate_results': False, 'user_supplied_reffile': None, 'nints_to_phase': None, 'nbins': None, 'scale_reference': True}
# 2024-02-21 02:37:29,554 - stpipe.Detector1Pipeline.emicorr - INFO - Step skipped.
# 2024-02-21 02:37:29,556 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr done
# 2024-02-21 02:37:29,629 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:29,630 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'n_pix_grow_sat': 1}
# 2024-02-21 02:37:29,643 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_saturation_0035.fits
# 2024-02-21 02:37:29,668 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:37:29,676 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:37:31,414 - stpipe.Detector1Pipeline.saturation - INFO - Detected 318 saturated pixels
# 2024-02-21 02:37:31,441 - stpipe.Detector1Pipeline.saturation - INFO - Detected 22 A/D floor pixels
# 2024-02-21 02:37:31,447 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2024-02-21 02:37:31,521 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:31,522 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:37:31,523 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2024-02-21 02:37:31,525 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2024-02-21 02:37:31,596 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:31,597 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:37:31,719 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2024-02-21 02:37:31,801 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:31,802 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:37:31,927 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2024-02-21 02:37:32,001 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:32,002 - stpipe.Detector1Pipeline.reset - INFO - Step reset parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:37:32,014 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_reset_0079.fits
# 2024-02-21 02:37:32,084 - stpipe.Detector1Pipeline.reset - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:37:32,093 - stpipe.Detector1Pipeline.reset - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:37:32,293 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2024-02-21 02:37:32,369 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:32,370 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:37:32,384 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_linearity_0033.fits
# 2024-02-21 02:37:32,413 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:37:32,421 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:37:32,848 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2024-02-21 02:37:32,920 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:32,921 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'type': 'baseline'}
# 2024-02-21 02:37:32,934 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_rscd_0016.fits
# 2024-02-21 02:37:33,078 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2024-02-21 02:37:33,154 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:33,155 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'dark_output': None}
# 2024-02-21 02:37:33,167 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_dark_0093.fits
# 2024-02-21 02:37:34,824 - stpipe.Detector1Pipeline.dark_current - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:37:34,840 - stpipe.Detector1Pipeline.dark_current - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:37:34,845 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=4, ngroups=21, nframes=1, groupgap=0
# 2024-02-21 02:37:34,846 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2024-02-21 02:37:35,854 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2024-02-21 02:37:35,940 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:35,941 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}
# 2024-02-21 02:37:36,104 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2024-02-21 02:37:36,104 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2024-02-21 02:37:36,105 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2024-02-21 02:37:36,105 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2024-02-21 02:37:36,105 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2024-02-21 02:37:36,105 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2024-02-21 02:37:36,106 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2024-02-21 02:37:36,106 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2024-02-21 02:37:36,106 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2024-02-21 02:37:36,661 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2024-02-21 02:37:36,738 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2024-02-21 02:37:36,813 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:36,814 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'signal_threshold': 25000.0}
# 2024-02-21 02:37:36,815 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2024-02-21 02:37:36,817 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration done
# 2024-02-21 02:37:36,887 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:36,889 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 100, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0, 'expand_large_events': False, 'min_sat_area': 1.0, 'min_jump_area': 5.0, 'expand_factor': 2.0, 'use_ellipses': False, 'sat_required_snowball': True, 'min_sat_radius_extend': 2.5, 'sat_expand': 2, 'edge_size': 25, 'find_showers': True, 'extend_snr_threshold': 1.2, 'extend_min_area': 90, 'extend_inner_radius': 1.0, 'extend_outer_radius': 2.6, 'extend_ellipse_expand_ratio': 1.1, 'time_masked_after_shower': 15.0, 'max_extended_radius': 200, 'minimum_groups': 3, 'minimum_sigclip_groups': 100, 'only_use_ints': True}
# 2024-02-21 02:37:36,897 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2024-02-21 02:37:36,897 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2024-02-21 02:37:36,907 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_gain_0006.fits
# 2024-02-21 02:37:36,943 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_readnoise_0086.fits
# 2024-02-21 02:37:37,179 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2024-02-21 02:37:37,354 - stpipe.Detector1Pipeline.jump - INFO - Creating 14 processes for jump detection
# 2024-02-21 02:37:43,229 - stpipe.Detector1Pipeline.jump - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/stcal/jump/jump.py:851: RuntimeWarning: All-NaN slice encountered
#   median_diffs = np.nanmedian(first_diffs_masked[intg], axis=0)
#
# 2024-02-21 02:37:43,459 - stpipe.Detector1Pipeline.jump - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/astropy/convolution/convolve.py:428: AstropyUserWarning: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this.
#   warnings.warn(
#
# 2024-02-21 02:37:55,573 - stpipe.Detector1Pipeline.jump - INFO - Total showers= 23
# 2024-02-21 02:37:55,574 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 18.3938 sec
# 2024-02-21 02:37:55,668 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 18.770787
# 2024-02-21 02:37:55,674 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2024-02-21 02:37:55,741 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:37:55,742 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2024-02-21 02:37:55,761 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_readnoise_0086.fits
# 2024-02-21 02:37:55,762 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_gain_0006.fits
# 2024-02-21 02:37:55,795 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2024-02-21 02:37:55,795 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2024-02-21 02:37:56,064 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2024-02-21 02:37:56,065 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2024-02-21 02:37:56,065 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 14
# 2024-02-21 02:38:02,188 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2024-02-21 02:38:02,256 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:38:02,257 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:38:02,283 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2024-02-21 02:38:02,284 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2024-02-21 02:38:02,287 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2024-02-21 02:38:02,359 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(4, 1024, 1032) from jw01640011001_04101_00001_mirifulong_uncal.fits>,).
# 2024-02-21 02:38:02,360 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:38:02,388 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2024-02-21 02:38:02,389 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2024-02-21 02:38:02,393 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2024-02-21 02:38:02,480 - stpipe.Detector1Pipeline - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/jw01640011001_04101_00001_mirifulong_rateints.fits
# 2024-02-21 02:38:02,481 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2024-02-21 02:38:02,482 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_1188.pmap
# 2024-02-21 02:38:02,523 - stpipe.Detector1Pipeline - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/jw01640011001_04101_00001_mirifulong_rate.fits
# 2024-02-21 02:38:02,524 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# /home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_
 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0, 'expand_large_events': False, 'min_sat_area': 1.0, 'min_jump_area': 5.0, 'expand_factor': 2.0, 'use_ellipses': False, 'sat_required_snowball': True, 'min_sat_radius_extend': 2.5, 'sat_expand': 2, 'edge_size': 25, 'find_showers': True, 'extend_snr_threshold': 1.2, 'extend_min_area': 90, 'extend_inner_radius': 1.0, 'extend_outer_radius': 2.6, 'extend_ellipse_expand_ratio': 1.1, 'time_masked_after_shower': 15.0, 'max_extended_radius': 200, 'minimum_groups': 3, 'minimum_sigclip_groups': 100, 'only_use_ints': True}
# 2024-02-21 02:39:18,194 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2024-02-21 02:39:18,194 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2024-02-21 02:39:18,202 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_gain_0006.fits
# 2024-02-21 02:39:18,227 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_readnoise_0086.fits
# 2024-02-21 02:39:18,459 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2024-02-21 02:39:18,532 - stpipe.Detector1Pipeline.jump - INFO - Creating 14 processes for jump detection
# 2024-02-21 02:39:24,185 - stpipe.Detector1Pipeline.jump - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/stcal/jump/jump.py:851: RuntimeWarning: All-NaN slice encountered
#   median_diffs = np.nanmedian(first_diffs_masked[intg], axis=0)
#
# 2024-02-21 02:39:24,424 - stpipe.Detector1Pipeline.jump - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/astropy/convolution/convolve.py:428: AstropyUserWarning: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this.
#   warnings.warn(
#
# 2024-02-21 02:39:36,314 - stpipe.Detector1Pipeline.jump - INFO - Total showers= 17
# 2024-02-21 02:39:36,314 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 17.855 sec
# 2024-02-21 02:39:36,404 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 18.210216
# 2024-02-21 02:39:36,408 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2024-02-21 02:39:36,486 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(4, 21, 1024, 1032) from jw01640011001_04101_00004_mirifulong_uncal.fits>,).
# 2024-02-21 02:39:36,487 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2024-02-21 02:39:36,507 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_readnoise_0086.fits
# 2024-02-21 02:39:36,508 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_gain_0006.fits
# 2024-02-21 02:39:36,544 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2024-02-21 02:39:36,545 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2024-02-21 02:39:36,818 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2024-02-21 02:39:36,819 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2024-02-21 02:39:36,820 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 14
# 2024-02-21 02:39:42,689 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2024-02-21 02:39:42,762 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00004_mirifulong_uncal.fits>,).
# 2024-02-21 02:39:42,763 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:39:42,791 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2024-02-21 02:39:42,792 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2024-02-21 02:39:42,795 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2024-02-21 02:39:42,866 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(4, 1024, 1032) from jw01640011001_04101_00004_mirifulong_uncal.fits>,).
# 2024-02-21 02:39:42,867 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/input/sci_input'}
# 2024-02-21 02:39:42,896 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2024-02-21 02:39:42,896 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2024-02-21 02:39:42,901 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2024-02-21 02:39:42,982 - stpipe.Detector1Pipeline - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/jw01640011001_04101_00004_mirifulong_rateints.fits
# 2024-02-21 02:39:42,983 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2024-02-21 02:39:42,985 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_1188.pmap
# 2024-02-21 02:39:43,028 - stpipe.Detector1Pipeline - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/jw01640011001_04101_00004_mirifulong_rate.fits
# 2024-02-21 02:39:43,029 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# Now let's look for input files of the form *uncal.fits from the background observation
sstring = input_bgdir + 'jw*mirifu*uncal.fits'

lvl1b_files = np.array(sorted(glob.glob(sstring)))

# If desired, check that these are the band/channel to use
if ((use_ch != '')&(use_band != '')):
    keep=np.zeros(len(lvl1b_files))
    for ii in range(0,len(lvl1b_files)):
        hdu=fits.open(lvl1b_files[ii])
        hdr=hdu[0].header
        if ((hdr['CHANNEL'] == use_ch)&(hdr['BAND'] == use_band)):
            keep[ii]=1
        hdu.close()
    indx=np.where(keep == 1)
    lvl1b_files=lvl1b_files[indx]

print('Found ' + str(len(lvl1b_files)) + ' background input files')
# Out:
# Found 0 background input files

# %%
# Run the pipeline on these input files by a simple loop over our pipeline function
if dodet1bg:
    for file in lvl1b_files:
        rundet1(file, det1_bgdir)
else:
    print('Skipping Detector1 processing for BG data')
# Out:
# Skipping Detector1 processing for BG data

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 137.8285 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 4.<font color='white'>-</font>Spec2 Pipeline <a class="anchor" id="spec2"></a>
# ------------------
#
# <div class="alert alert-block alert-warning">
# In this section we process our data through the Spec2 pipeline in order to produce Lvl2b data products (i.e., calibrated slope images and quick-look data cubes and 1d spectra).
#
# See https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_spec2.html
# </div>
#
# During stage 2 of the pipeline, the countrate (slope) image products from stage 1, which have units of DN/s, are converted to units of surface brightness (MJy/sr) for both extended and point sources (as of DMS build 9.3/CAL_VER 1.10.2).
#
# If Pixel based background subtraction was chosen, this will be applied during Spec2. Doing the Pixel based background subtraction requires an association file to be created to associate the background files with individual science files.

# %%
time_spec2 = time.perf_counter()

# %%
# Define a useful function to write out a Lvl2 association file
# Requires *one* input sci file, but can have multiple input bg file
# The background will not be applied properly to all files if more than *one* sci file is included in the association.
def writel2asn(onescifile, bgfiles, asnfile, prodname):
    # Define the basic association of science files
    asn = afl.asn_from_list([onescifile], rule=DMSLevel2bBase, product_name=prodname) # Wrap in array since input was single exposure
    
    # Channel/band configuration for this sci file
    hdu=fits.open(onescifile)
    hdr=hdu[0].header
    this_channel, this_band = hdr['CHANNEL'], hdr['BAND']
    hdu.close()
    
    # If backgrounds were provided, find which are appropriate to this channel/band and add to association
    nbg=len(bgfiles)
    if (nbg > 0):
        for ii in range(0,nbg):
            hdu=fits.open(bgfiles[ii])
            hdr=hdu[0].header
            if ((hdr['CHANNEL'] == this_channel)&(hdr['BAND'] == this_band)):
                asn['products'][0]['members'].append({'expname': bgfiles[ii], 'exptype': 'background'})
            hdu.close()
        
    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %%
# Find and sort all of the input files

sstring = det1_dir + 'jw*mirifu*rate.fits' #use files from run_folder
ratefiles = np.array(sorted(glob.glob(sstring)))

# If desired, check that these sci files are the band/channel to use
if ((use_ch != '')&(use_band != '')):
    keep=np.zeros(len(ratefiles))
    for ii in range(0,len(ratefiles)):
        hdu=fits.open(ratefiles[ii])
        hdr=hdu[0].header
        if ((hdr['CHANNEL'] == use_ch)&(hdr['BAND'] == use_band)):
            keep[ii]=1
        hdu.close()
    indx=np.where(keep == 1)
    ratefiles=ratefiles[indx]
    
# Background Files
sstring = det1_bgdir + 'jw*mirifu*rate.fits' 
bgfiles = np.array(sorted(glob.glob(sstring)))

# If desired, check that these bg files are the band/channel to use
if ((use_ch != '')&(use_band != '')):
    keep=np.zeros(len(bgfiles))
    for ii in range(0,len(bgfiles)):
        hdu=fits.open(bgfiles[ii])
        hdr=hdu[0].header
        if ((hdr['CHANNEL'] == use_ch)&(hdr['BAND'] == use_band)):
            keep[ii]=1
        hdu.close()
    indx=np.where(keep == 1)
    bgfiles=bgfiles[indx]

print('Found ' + str(len(ratefiles)) + ' science files')
print('Found ' + str(len(bgfiles)) + ' background files')
# Out:
# Found 4 science files
# Found 0 background files

# %%
# Define a function that will call the spec2 pipeline with our desired set of parameters
# We'll list the individual steps just to make it clear what's running
def runspec2(filename, outdir, nocubes=False):
    print(filename)
    # Set default configuration from CRDS param reference files.
    # -This is required when running the pipeline in a function.
    crds_config = Spec2Pipeline.get_config_from_reference(filename)
    spec2 = Spec2Pipeline.from_config_section(crds_config)
    
    spec2.output_dir = outdir

    # Assign_wcs overrides
    #spec2.assign_wcs.override_distortion = 'myfile.asdf'
    #spec2.assign_wcs.override_regions = 'myfile.asdf'
    #spec2.assign_wcs.override_specwcs = 'myfile.asdf'
    #spec2.assign_wcs.override_wavelengthrange = 'myfile.asdf'
    
    # Background overrides were set up above
    if (pixel_bg == True):
        spec2.bkg_subtract.skip = False
    else:
        spec2.bkg_subtract.skip = True

    # Flatfield overrides
    #spec2.flat_field.override_flat = 'myfile.fits'
        
    # Straylight overrides
    #spec2.straylight.override_mrsxartcorr = 'myfile.fits'
        
    # Fringe overrides
    #spec2.fringe.override_fringe = 'myfile.fits'
    
    # Photom overrides
    #spec2.photom.override_photom = 'myfile.fits'

    # Cubepar overrides
    #spec2.cube_build.override_cubepar = 'myfile.fits'
        
    # Extract1D overrides
    #spec2.extract_1d.override_extract1d = 'myfile.asdf'
    #spec2.extract_1d.override_apcorr = 'myfile.asdf'
        
    # Overrides for whether or not certain steps should be skipped
    #spec2.assign_wcs.skip = False
    #spec2.bkg_subtract.skip = True
    #spec2.flat_field.skip = False
    #spec2.srctype.skip = False
    #spec2.straylight.skip = False
    #spec2.fringe.skip = False
    #spec2.photom.skip = False
    #spec2.residual_fringe.skip = False #does a residual fringe correction across the entire cube
    #spec2.cube_build.skip = False
    #spec2.extract_1d.skip = False
    
    # Run pixel replacement code to extrapolate values for otherwise bad pixels.
    # This can help mitigate small 5-10% negative dips in spectra of bright sources.
    spec2.pixel_replace.skip=False
    spec2.pixel_replace.algorithm='mingrad'
    
    # This nocubes option allows us to skip the cube building and 1d spectral extraction for individual
    # science data frames, but run it for the background data (as the 1d spectra are needed later
    # for the master background step in Spec3)
    if (nocubes):
        spec2.cube_build.skip = True
        spec2.extract_1d.skip = True
    
    # Some cube building options
    #spec2.cube_build.weighting='drizzle'
    #spec2.cube_build.coord_system='ifualign' # If aligning cubes with IFU axes instead of sky
      
    spec2.save_results = True
    spec2(filename)

# %%
# Step through each of the science files, using relevant associated backgrounds in spec2 processing
# The background files are used in this step to perform pixel-based background subtraction (if desired) 
# Otherwise Background subtraction is done later with Spec3 files
if dospec2:
    for file in ratefiles:
        asnfile=os.path.join(output_dir, 'l2asn.json')
        writel2asn(file, bgfiles, asnfile, 'Level2')
        runspec2(asnfile, spec2_dir, nocubes=True)
else:
    print('Skipping Spec2 processing for SCI data')
# Out:
# 2024-02-21 02:39:43,131 - stpipe - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024
- stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2024-02-21 02:41:51,447 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00004_mirifulong_rate.fits>,).
# 2024-02-21 02:41:51,447 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2024-02-21 02:41:51,511 - stpipe.Spec2Pipeline.flat_field - INFO - Using FLAT reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_flat_0815.fits
# 2024-02-21 02:41:51,512 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2024-02-21 02:41:51,512 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2024-02-21 02:41:51,512 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2024-02-21 02:41:51,812 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2024-02-21 02:41:51,971 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00004_mirifulong_rate.fits>,).
# 2024-02-21 02:41:51,972 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out'}
# 2024-02-21 02:41:51,984 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_fringe_0070.fits
# 2024-02-21 02:41:52,008 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:41:52,009 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:41:52,009 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:41:52,279 - stpipe.Spec2Pipeline.fringe - INFO - DQ values in the reference file NOT used to update the output DQ.
# 2024-02-21 02:41:52,282 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2024-02-21 02:41:52,446 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00004_mirifulong_rate.fits>,).
# 2024-02-21 02:41:52,448 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'inverse': False, 'source_type': None, 'user_slit_loc': None}
# 2024-02-21 02:41:52,448 - stpipe.Spec2Pipeline.pathloss - INFO - Step skipped.
# 2024-02-21 02:41:52,450 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2024-02-21 02:41:52,580 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00004_mirifulong_rate.fits>,).
# 2024-02-21 02:41:52,581 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'inverse': False, 'source_type': None}
# 2024-02-21 02:41:52,581 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2024-02-21 02:41:52,583 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2024-02-21 02:41:52,712 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00004_mirifulong_rate.fits>,).
# 2024-02-21 02:41:52,713 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}
# 2024-02-21 02:41:52,731 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_photom_0197.fits
# 2024-02-21 02:41:52,732 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2024-02-21 02:41:52,994 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2024-02-21 02:41:52,995 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFULONG
# 2024-02-21 02:41:52,995 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2024-02-21 02:41:52,996 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2024-02-21 02:41:53,042 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-02-21 02:41:53,043 - stpipe.Spec2Pipeline.photom - WARNING - The PIXAR_SR keyword is missing from jwst_miri_photom_0197.fits
# 2024-02-21 02:41:53,043 - stpipe.Spec2Pipeline.photom - WARNING - The PIXAR_A2 keyword is missing from jwst_miri_photom_0197.fits
# 2024-02-21 02:41:53,054 - stpipe.Spec2Pipeline.photom - INFO - Applying MRS IFU time dependent correction.
# 2024-02-21 02:41:53,404 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2024-02-21 02:41:53,562 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00004_mirifulong_rate.fits>,).
# 2024-02-21 02:41:53,564 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'residual_fringe', 'search_output_file': False, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'save_intermediate_results': False, 'ignore_region_min': None, 'ignore_region_max': None}
# 2024-02-21 02:41:53,564 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step skipped.
# 2024-02-21 02:41:53,566 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe done
# 2024-02-21 02:41:53,697 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step pixel_replace running with args (<IFUImageModel(1024, 1032) from jw01640011001_04101_00004_mirifulong_rate.fits>,).
# 2024-02-21 02:41:53,698 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step pixel_replace parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'algorithm': 'mingrad', 'n_adjacent_cols': 3}
# 2024-02-21 02:41:54,394 - stpipe.Spec2Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2024-02-21 02:41:54,710 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input MRS frame had 3585 total pixels replaced.
# 2024-02-21 02:41:54,712 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step pixel_replace done
# 2024-02-21 02:41:55,362 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage2/jw01640011001_04101_00004_mirifulong_cal.fits>,).
# 2024-02-21 02:41:55,363 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scalexy': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'ra_center': None, 'dec_center': None, 'cube_pa': None, 'nspax_x': None, 'nspax_y': None, 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': True, 'debug_spaxel': '-1 -1 -1'}
# 2024-02-21 02:41:55,364 - stpipe.Spec2Pipeline.cube_build - INFO - Step skipped.
# 2024-02-21 02:41:55,366 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2024-02-21 02:41:55,789 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<IFUImageModel(1024, 1032) from /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage2/jw01640011001_04101_00004_mirifulong_cal.fits>,).
# 2024-02-21 02:41:55,790 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'ifu_autocen': False, 'ifu_rfcorr': False, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2024-02-21 02:41:55,790 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2024-02-21 02:41:55,793 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2024-02-21 02:41:55,793 - stpipe.Spec2Pipeline - INFO - Finished processing product /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage1/jw01640011001_04101_00004_mirifulong
# 2024-02-21 02:41:55,794 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2024-02-21 02:41:55,795 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1188.pmap
# 2024-02-21 02:41:56,215 - stpipe.Spec2Pipeline - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage2/jw01640011001_04101_00004_mirifulong_cal.fits
# 2024-02-21 02:41:56,215 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %%
# Now reduce the backgrounds individually
# This will be needed for the Masterbackgroud step in Spec3. You can skip this if doing Spec2 pixel based background.
if dospec2bg:
    for file in bgfiles:
        runspec2(file, spec2_bgdir)
else:
    print('Skipping Spec2 processing for BG data')
# Out:
# Skipping Spec2 processing for BG data

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
print(f"Runtime for Spec2: {time1 - time_spec2} seconds")
# Out:
# Runtime so far: 270.9988 seconds
# Runtime for Spec2: 133.16107249003835 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 5.<font color='white'>-</font>Spec3 Pipeline: Default configuration<a class="anchor" id="spec3"></a>
# ------------------
#
# <div class="alert alert-block alert-warning">
# Here we'll run the Spec3 pipeline to produce a composite data cube from all dithered exposures.
# We will need to create an association file from all science and background data in order for the pipeline to use them appropriately.
#
# A word of caution: the data cubes created by the JWST pipeline are in SURFACE BRIGHTNESS units (MJy/steradian), not flux units.  What that means is that if you intend to sum spectra within an aperture you need to be sure to multiply by the pixel area in steradians first in order to get a spectrum in flux units (the PIXAR_SR keyword can be found in the SCI extension header).  This correction is already build into the pipeline Extract1D algorithm.
#
# See https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_spec3.html
#
# </div>
#
# Spec3 requires an association file to be created to associate the individual _cal.fits science exposures together to be combined into a final combined data cube.
# <br>
# - If Master background subtraction was chosen, this will be applied during Spec3. Doing the Background subtraction requires the association file to be created to associate the background _x1d.fits files with all science files. For Master Background subtraction the association file must contain all _x1d.fits background files created with Spec2 and all _cal.fits science files to be combined into the final background subtracted science cube.
# <br>
#
# The extract_1d step is controlled by a different set of parameters in the EXTRACT1D reference file.
# <br>
# For point sources:
# >For point sources a circular extraction aperture is used, along with an optional circular annulus for background extraction and subtraction. The size of the extraction region and the background annulus size varies with wavelength. The extraction related vectors are found in the asdf extract1d reference file. [More Info ...](https://jwst-pipeline.readthedocs.io/en/latest/jwst/extract_1d/description.html)
#
# For extended targets:
# > For an extended source, rectangular aperture photometry is used, with the entire image being extracted, and no background subtraction, regardless of what was specified in the reference file or step arguments. [More Info ...](https://jwst-pipeline.readthedocs.io/en/latest/jwst/extract_1d/description.html)
# >
# > Note: Since the Field-of-view for the MRS changes between the different channels, the extraction region size will be difference for the different channels

# %%
time_spec3 = time.perf_counter()

# %%
# Define a useful function to write out a Lvl3 association file from an input list
# Note that any background exposures have to be of type x1d.
def writel3asn(scifiles, bgfiles, asnfile, prodname):
    # Define the basic association of science files
    asn = afl.asn_from_list(scifiles, rule=DMS_Level3_Base, product_name=prodname)
        
    # Add background files to the association
    nbg=len(bgfiles)
    for ii in range(0,nbg):
        asn['products'][0]['members'].append({'expname': bgfiles[ii], 'exptype': 'background'})
        
    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %%
# Find and sort all of the input files

# Science Files need the cal.fits files
sstring = spec2_dir + 'jw*mirifu*cal.fits'
calfiles = np.array(sorted(glob.glob(sstring)))

# If desired, check that these are the band/channel to use
if ((use_ch != '')&(use_band != '')):
    keep=np.zeros(len(calfiles))
    for ii in range(0,len(calfiles)):
        hdu=fits.open(calfiles[ii])
        hdr=hdu[0].header
        if ((hdr['CHANNEL'] == use_ch)&(hdr['BAND'] == use_band)):
            keep[ii]=1
        hdu.close()
    indx=np.where(keep == 1)
    calfiles=calfiles[indx]

# Background Files need the x1d.fits files for Master Background subtraction
sstring = spec2_bgdir + 'jw*mirifu*x1d.fits'
bgfiles = np.array(sorted(glob.glob(sstring)))

print('Found ' + str(len(calfiles)) + ' science files to process')
print('Found ' + str(len(bgfiles)) + ' background files to process')
# Out:
# Found 4 science files to process
# Found 0 background files to process

# %%
# Make an association file that includes all of the different exposures.
# _cal.fits science files and _x1d.fits files if doing Master Background subtraction
asnfile=os.path.join(output_dir, 'l3asn.json')
if dospec3:
    writel3asn(calfiles, bgfiles, asnfile, 'Level3')
# Out:
# 2024-02-21 02:41:56,289 - stpipe - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)

# %%
# Define a function that will call the spec3 pipeline with our desired set of parameters
# This is designed to run on an association file
def runspec3(filename):
    # Set default configuration from CRDS param reference files
    # -This is required when running the pipeline in a function.
    crds_config = Spec3Pipeline.get_config_from_reference(filename)
    spec3 = Spec3Pipeline.from_config_section(crds_config)
    
    spec3.output_dir = spec3_dir
    spec3.save_results = True
    
    # Background overrides were set up above
    if (master_bg == True):
        spec3.master_background.skip = False
    else:
        spec3.master_background.skip = True
    
    # Overrides for whether or not certain other steps should be skipped
    #spec3.assign_mtwcs.skip = False
    spec3.outlier_detection.skip = False
    spec3.outlier_detection.kernel_size = '11 1'
    spec3.outlier_detection.threshold_percent = 99.5 # Dial this threshold if necessary to be more/less aggressive in outlier flagging
    #spec3.mrs_imatch.skip = True
    #spec3.cube_build.skip = True
    #spec3.extract_1d.skip = False
    #spec3.spectral_leak.skip = True
    
    # Cube building configuration options
    #spec3.cube_build.override_cubepar = 'myfile.fits' # Cubepar parameter override
    spec3.cube_build.output_file = 'mycube' # Custom output name
    spec3.cube_build.output_type = 'band' # 'band', 'channel', or 'multi' type cube output
    #spec3.cube_build.channel = '1' # Build everything from just channel 1 into a single cube (we could also choose '2','3','4', or 'ALL')
    #spec3.cube_build.weighting = 'drizzle' # 'emsm' or 'drizzle'
    #spec3.cube_build.coord_system = 'ifualign' # 'ifualign', 'skyalign', or 'internal_cal'
    #spec3.cube_build.scalexy = 0.5 # Output cube spaxel scale (arcsec) if setting it by hand
    #spec3.cube_build.scalew = 0.002 # Output cube voxel depth in wavelength if setting it by hand
    #spec3.cube_build.ra_center = 65.0 # Force cube to be centered at this R.A.
    #spec3.cube_build.dec_center = -35.0 # Force cube to be centered at this Decl.
    #spec3.cube_build.cube_pa = 45.0 # Force cube to have this position angle
    #spec3.cube_build.nspax_x = 61 # Require this number of spaxels in cube X direction
    #spec3.cube_build.nspax_y = 61 # Require this number of spaxels in cube Y direction
    #spec3.cube_build.wavemin = 4.8 # Custom minimum wavelength for the cube
    #spec3.cube_build.wavemax = 6.3 # Custom maximum wavelength for the cube
        
    # Extract1D overrides and config options
    #spec3.extract_1d.override_extract1d = 'myfile.asdf'
    #spec3.extract_1d.override_apcorr = 'myfile.asdf'
    #spec3.extract_1d.ifu_set_srctype = 'POINT' # Force a certain type of spectral extraction
    #spec3.extract_1d.ifu_rscale = 2 # Number of FWHM to use for point-source aperture extraction radius (default is 2)
    spec3.extract_1d.ifu_autocen = True # Enable auto-centering of the extraction aperture
    #spec3.extract_1d.center_xy=(20,20) # Override aperture location if desired
    spec3.extract_1d.ifu_rfcorr = True # Turn on 1d residual fringe correction

    spec3(filename)

# %%
if dospec3:
    runspec3(asnfile)
else:
    print('Skipping Spec3 processing')
# Out:
# 2024-02-21 02:41:57,172 - stpipe - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0052.asdf
# 2024-02-21 02:41:57,180 - CRDS - ERROR -  Error determining best reference for 'pars-spectralleakstep'  =   Unknown reference type 'pars-spectralleakstep'
# 2024-02-21 02:41:57,181 - stpipe - INFO - PARS-SPEC3PIPELINE parameters found: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_pars-spec3pipeline_0005.asdf
# 2024-02-21 02:41:57,192 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2024-02-21 02:41:57,193 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2024-02-21 02:41:57,194 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2024-02-21 02:41:57,195 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2024-02-21 02:41:57,196 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2024-02-21 02:41:57,197 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2024-02-21 02:41:57,198 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2024-02-21 02:41:57,199 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2024-02-21 02:41:57,200 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2024-02-21 02:41:57,200 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2024-02-21 02:41:57,201 - stpipe.Spec3Pipeline.spectral_leak - INFO - SpectralLeakStep instance created.
# 2024-02-21 02:41:57,308 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/l3asn.json',).
# 2024-02-21 02:41:57,313 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'kernel_size': '11 1', 'threshold_percent': 99.5, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': '/home/ev-linux/JWST-3D/mycube', 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scalexy': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'ra_center': None, 'dec_center': None, 'cube_pa': None, 'nspax_x': None, 'nspax_y': None, 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False, 'debug_spaxel': '-1 -1 -1'}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'ifu_autocen': True, 'ifu_rfcorr': True, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'so ...
# 2024-02-21 02:41:57,323 - stpipe.Spec3Pipeline - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024-02-21 02:41:57,979 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw01640011001_04101_00001_mirifulong_cal.fits' reftypes = ['apcorr', 'area', 'cubepar', 'drizpars', 'extract1d', 'mrsptcorr', 'photom', 'speckernel', 'specprofile', 'spectrace', 'wavemap']
# 2024-02-21 02:41:57,981 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri
- stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'ifu_autocen': True, 'ifu_rfcorr': True, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2024-02-21 02:42:27,527 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2024-02-21 02:42:27,533 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_apcorr_0006.asdf
# 2024-02-21 02:42:28,774 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2024-02-21 02:42:28,785 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2024-02-21 02:42:28,787 - stpipe.Spec3Pipeline.extract_1d - INFO - Using auto source detection.
# 2024-02-21 02:42:28,861 - stpipe.Spec3Pipeline.extract_1d - INFO - Auto source detection success.
# 2024-02-21 02:42:28,861 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 20.5031, y_center = 26.0061
# 2024-02-21 02:42:30,400 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying 1d residual fringe correction.
# 2024-02-21 02:42:30,973 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2024-02-21 02:42:31,225 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2024-02-21 02:42:31,233 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_apcorr_0004.asdf
# 2024-02-21 02:42:32,460 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2024-02-21 02:42:32,469 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2024-02-21 02:42:32,470 - stpipe.Spec3Pipeline.extract_1d - INFO - Using auto source detection.
# 2024-02-21 02:42:32,492 - stpipe.Spec3Pipeline.extract_1d - INFO - Auto source detection success.
# 2024-02-21 02:42:32,493 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 15.9108, y_center = 15.6986
# 2024-02-21 02:42:33,503 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying 1d residual fringe correction.
# 2024-02-21 02:42:34,052 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2024-02-21 02:42:34,242 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2024-02-21 02:42:34,431 - stpipe.Spec3Pipeline.spectral_leak - INFO - Step spectral_leak running with args (<ModelContainer>,).
# 2024-02-21 02:42:34,433 - stpipe.Spec3Pipeline.spectral_leak - INFO - Step spectral_leak parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out'}
# 2024-02-21 02:42:34,461 - stpipe.Spec3Pipeline.spectral_leak - INFO - Found CH 3A in the input data
# 2024-02-21 02:42:34,463 - stpipe.Spec3Pipeline.spectral_leak - WARNING - CH1B and CH3A were not found. No spectral leak correction
# 2024-02-21 02:42:34,522 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/mycube_ch3-short_x1d.fits
# 2024-02-21 02:42:34,576 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/mycube_ch4-short_x1d.fits
# 2024-02-21 02:42:34,576 - stpipe.Spec3Pipeline.spectral_leak - INFO - Step spectral_leak done
# 2024-02-21 02:42:34,580 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2024-02-21 02:42:34,580 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
print(f"Runtime for Spec3: {time1 - time_spec3} seconds")
# Out:
# Runtime so far: 309.3538 seconds
# Runtime for Spec3: 38.345198294031434 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 6.<font color='white'>-</font>Plot the spectra<a class="anchor" id="plots"></a>
# ------------------
#
# <div class="alert alert-block alert-warning">
# Here we'll plot the spectra to see what our source looks like.
#
# For MIRI-MRS, all extract-1d files are in Flux units of Jy
#
# </div>

# %%
# Find and sort all of the input files

# Science Files 
# Use the finale extracted spectra (x1d.fits) files 
sstring = spec3_dir + '*x1d.fits'
x1dfiles = np.array(sorted(glob.glob(sstring)))

# %%
# Normal plots
# %matplotlib inline
# Interactive plots
#%matplotlib notebook

rc('axes', linewidth=2)
fig, ax = plt.subplots(1,1, figsize=(10,3), dpi=150)

if (len(x1dfiles) > 0):
    hdu=fits.open(x1dfiles[0])
    objname=hdu[0].header['TARGPROP']
else:
    objname='Unknown'

ymin,ymax=np.nan,np.nan
for file in x1dfiles:
    x1d=fits.open(file)
    x1ddata=x1d[1].data
    wave=x1ddata['WAVELENGTH']
    flux=x1ddata['FLUX']
    ymin=np.nanmin([ymin,np.nanpercentile(flux,2)])
    ymax=np.nanmax([ymax,np.nanpercentile(flux,99.5)])
    
    # labels
    label=x1d[0].header['CHANNEL']+x1d[0].header['BAND']
    
    plt.plot(wave,flux,label=label)
    
plt.xlabel(r'Wavelength ($\mu$m)')
plt.ylabel('Flux (Jy)')
plt.title(objname)
plt.ylim(ymin,ymax)
plt.legend(fontsize=8, loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid()

# %% [markdown]
# # 5.-Spec3 Pipeline: Default configuration (4 per-channel cubes)

# %%
# Define a useful function to write out a Lvl3 association file from an input list
# Note that any background exposures have to be of type x1d.
def writel3asn(scifiles, bgfiles, asnfile, prodname):
    # Define the basic association of science files
    asn = afl.asn_from_list(scifiles, rule=DMS_Level3_Base, product_name=prodname)
        
    # Add background files to the association
    nbg=len(bgfiles)
    for ii in range(0,nbg):
        asn['products'][0]['members'].append({'expname': bgfiles[ii], 'exptype': 'background'})
        
    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %%
# Find and sort all of the input files

# Science Files need the cal.fits files
sstring = spec2_dir + 'jw*mirifu*cal.fits'
calfiles = np.array(sorted(glob.glob(sstring)))

# Background Files need the x1d.fits files
sstring = spec2_bgdir + 'jw*mirifu*x1d.fits'
bgfiles = np.array(sorted(glob.glob(sstring)))

print('Found ' + str(len(calfiles)) + ' science files to process')
print('Found ' + str(len(bgfiles)) + ' background files to process')
# Out:
# Found 20 science files to process
# Found 0 background files to process

# %%
# Make an association file that includes all of the different exposures
# It has to be in the working directory
asnfile=os.path.join('l3asn.json')
if dospec3:
    writel3asn(calfiles, bgfiles, asnfile, 'Level3')
# Out:
# 2024-02-21 02:42:34,949 - stpipe - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)

# %%
# Define a function that will call the spec3 pipeline with our desired set of parameters
# This is designed to run on an association file
def runspec3(filename):
    # This initial setup is just to make sure that we get the latest parameter reference files
    # pulled in for our files.  This is a temporary workaround to get around an issue with
    # how this pipeline calling method works.
    crds_config = Spec3Pipeline.get_config_from_reference(filename)
    spec3 = Spec3Pipeline.from_config_section(crds_config)
        
    spec3.output_dir = spec3_dir
    spec3.save_results = True
    
    # Cube building configuration options
    # spec3.cube_build.output_file = 'bandcube' # Custom output name
    # spec3.cube_build.output_type = 'band' # 'band', 'channel', or 'multi' type cube output
    # spec3.cube_build.channel = '1' # Build everything from just channel 1 into a single cube (we could also choose '2','3','4', or 'ALL')
    # spec3.cube_build.weighting = 'drizzle' # 'emsm' or 'drizzle'
    # spec3.cube_build.coord_system = 'ifualign' # 'ifualign', 'skyalign', or 'internal_cal'
    # spec3.cube_build.scale1 = 0.5 # Output cube spaxel scale (arcsec) in dimension 1 if setting it by hand
    # spec3.cube_build.scale2 = 0.5 # Output cube spaxel scale (arcsec) in dimension 2 if setting it by hand
    # spec3.cube_build.scalew = 0.002 # Output cube spaxel size (microns) in dimension 3 if setting it by hand
    
    # Overrides for whether or not certain steps should be skipped
    #spec3.assign_mtwcs.skip = False
    #spec3.master_background.skip = True
    #spec3.outlier_detection.skip = True
    #spec3.mrs_imatch.skip = True
    #spec3.cube_build.skip = False
    #spec3.extract_1d.skip = False
    
    # Cubepar overrides
    #spec3.cube_build.override_cubepar = 'myfile.fits'
        
    # Extract1D overrides
    #spec3.extract1d.override_extract1d = 'myfile.asdf'
    #spec3.extract1d.override_apcorr = 'myfile.asdf'

    spec3(filename)

# %%
if dospec3:
    runspec3(asnfile)
else:
    print('Skipping Spec3 processing')
# Out:
# 2024-02-21 02:42:35,781 - stpipe - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0052.asdf
# 2024-02-21 02:42:35,789 - CRDS - ERROR -  Error determining best reference for 'pars-spectralleakstep'  =   Unknown reference type 'pars-spectralleakstep'
# 2024-02-21 02:42:35,790 - stpipe - INFO - PARS-SPEC3PIPELINE parameters found: /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_pars-spec3pipeline_0005.asdf
# 2024-02-21 02:42:35,801 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2024-02-21 02:42:35,802 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2024-02-21 02:42:35,803 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2024-02-21 02:42:35,804 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2024-02-21 02:42:35,804 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2024-02-21 02:42:35,805 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2024-02-21 02:42:35,806 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2024-02-21 02:42:35,807 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2024-02-21 02:42:35,808 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2024-02-21 02:42:35,809 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2024-02-21 02:42:35,809 - stpipe.Spec3Pipeline.spectral_leak - INFO - SpectralLeakStep instance created.
# 2024-02-21 02:42:35,930 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('l3asn.json',).
# 2024-02-21 02:42:35,935 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'kernel_size': '11 1', 'threshold_percent': 99.5, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'channel', 'scalexy': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'ra_center': None, 'dec_center': None, 'cube_pa': None, 'nspax_x': None, 'nspax_y': None, 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False, 'debug_spaxel': '-1 -1 -1'}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'ifu_autocen': True, 'ifu_rfcorr': False, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss ...
# 2024-02-21 02:42:35,945 - stpipe.Spec3Pipeline - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024-02-21 02:42:36,522 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw01640011001_04101_00001_mirifulong_cal.fits' reftypes = ['apcorr', 'area', 'cubepar', 'drizpars', 'extract1d', 'mrsptcorr', 'photom', 'speckernel', 'specprofile', 'spectrace', 'wavemap']
# 2024-02-21 02:42:36,524 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_apcorr_0008.asdf'.
# 2024-02-21 02:42:36,525 - stpipe.Spec3Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2024-02-21 02:42:36,525 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits'.
# 2024-02-21 02:42:36,525 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2024-02-21 02:42:36,526 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf'.
# 2024-02-21 02:42:36,527 - stpipe.Spec3Pipeline - INFO - Prefetch for MRSPTCORR reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_mrsptcorr_0002.fits'.
# 2024-02-21 02:42:36,527 - stpipe.Spec3Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_photom_0197.fits'.
# 2024-02-21 02:42:36,527 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2024-02-21 02:42:36,528 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2024-02-21 02:42:36,528 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECTRACE reference file is 'N/A'.
# 2024-02-21 02:42:36,528 - stpipe.Spec3Pipeline - INFO - Prefetch for WAVEMAP reference file is 'N/A'.
# 2024-02-21 02:42:36,529 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2024-02-21 02:42:36,538 - stpipe.Spec3Pipeline - WARNING - /home/ev-linux/miniconda3/envs/stenv/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024-02-21 02:42:52,659 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch running with args (<ModelContainer>,).
# 2024-02-21 02:42:52,660 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'mrs_imatch', 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}
# 2024-02-21 02:42:52,661 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step skipped.
# 2024-02-21 02:42:52,692 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch done
# 2024-02-21 02:42:53,134 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2024-02-21 02:42:53,136 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'kernel_size': '11 1', 'threshold_percent': 99.5, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2024-02-21 02:42:53,141 - stpipe.Spec3Pipeline.outlier_detection - INFO - Performing outlier detection on 20 inputs
# 2024-02-21 02:42:53,141 - stpipe.Spec3Pipeline.outlier_detection - INFO - Performing IFU outlier_detection for exptype MIR_MRS
# 2024-02-21 02:42:53,737 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,742 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,747 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,752 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,757 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,764 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,771 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,776 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,783 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:53,788 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3691 (0.35%)
# 2024-02-21 02:42:54,302 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,307 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,312 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,317 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,323 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,328 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,333 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,338 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,343 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,348 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 4096 (0.39%)
# 2024-02-21 02:42:54,800 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_04101_00001_mirifulong_a3001_crf.fits
# 2024-02-21 02:42:55,323 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_04101_00001_mirifushort_a3001_crf.fits
# 2024-02-21 02:42:55,751 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_04101_00002_mirifulong_a3001_crf.fits
# 2024-02-21 02:42:56,280 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_04101_00002_mirifushort_a3001_crf.fits
# 2024-02-21 02:42:56,703 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_04101_00003_mirifulong_a3001_crf.fits
# 2024-02-21 02:42:57,697 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_04101_00003_mirifushort_a3001_crf.fits
# 2024-02-21 02:42:58,123 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_04101_00004_mirifulong_a3001_crf.fits
# 2024-02-21 02:42:58,661 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_04101_00004_mirifushort_a3001_crf.fits
# 2024-02-21 02:42:59,088 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_06101_00001_mirifulong_a3001_crf.fits
# 2024-02-21 02:42:59,624 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_06101_00001_mirifushort_a3001_crf.fits
# 2024-02-21 02:43:00,508 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_06101_00002_mirifulong_a3001_crf.fits
# 2024-02-21 02:43:01,042 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001_06101_00002_mirifushort_a3001_crf.fits
# 2024-02-21 02:43:01,462 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/jw01640011001
- stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2024-02-21 02:45:55,819 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2024-02-21 02:45:55,825 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_apcorr_0005.asdf
# 2024-02-21 02:45:56,883 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2024-02-21 02:45:56,892 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2024-02-21 02:45:56,898 - stpipe.Spec3Pipeline.extract_1d - INFO - Using auto source detection.
# 2024-02-21 02:45:57,195 - stpipe.Spec3Pipeline.extract_1d - INFO - Auto source detection success.
# 2024-02-21 02:45:57,195 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 22.7228, y_center = 21.1394
# 2024-02-21 02:46:03,927 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2024-02-21 02:46:04,806 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2024-02-21 02:46:04,812 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_apcorr_0004.asdf
# 2024-02-21 02:46:05,877 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2024-02-21 02:46:05,886 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2024-02-21 02:46:05,889 - stpipe.Spec3Pipeline.extract_1d - INFO - Using auto source detection.
# 2024-02-21 02:46:05,956 - stpipe.Spec3Pipeline.extract_1d - INFO - Auto source detection success.
# 2024-02-21 02:46:05,957 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 15.8473, y_center = 15.5445
# 2024-02-21 02:46:09,462 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2024-02-21 02:46:09,971 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2024-02-21 02:46:09,977 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/ev-linux/JWST-3D/cdrs_cache/references/jwst/miri/jwst_miri_apcorr_0007.asdf
# 2024-02-21 02:46:11,044 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = POINT
# 2024-02-21 02:46:11,054 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2024-02-21 02:46:11,063 - stpipe.Spec3Pipeline.extract_1d - INFO - Using auto source detection.
# 2024-02-21 02:46:11,461 - stpipe.Spec3Pipeline.extract_1d - INFO - Auto source detection success.
# 2024-02-21 02:46:11,461 - stpipe.Spec3Pipeline.extract_1d - INFO - Using x_center = 21.8807, y_center = 23.9599
# 2024-02-21 02:46:18,824 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2024-02-21 02:46:19,771 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2024-02-21 02:46:20,259 - stpipe.Spec3Pipeline.spectral_leak - INFO - Step spectral_leak running with args (<ModelContainer>,).
# 2024-02-21 02:46:20,261 - stpipe.Spec3Pipeline.spectral_leak - INFO - Step spectral_leak parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': ''}
# 2024-02-21 02:46:20,297 - stpipe.Spec3Pipeline.spectral_leak - INFO - Found CH 3A in the input data
# 2024-02-21 02:46:20,298 - stpipe.Spec3Pipeline.spectral_leak - INFO - Found CH 1B in the input data
# 2024-02-21 02:46:20,398 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/Level3_ch3-shortmediumlong_x1d.fits
# 2024-02-21 02:46:20,451 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/Level3_ch2-shortmediumlong_x1d.fits
# 2024-02-21 02:46:20,503 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/Level3_ch4-shortmediumlong_x1d.fits
# 2024-02-21 02:46:20,556 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in /home/ev-linux/JWST-3D/data/miri_mrs/mrs/output/sci_out/stage3/Level3_ch1-shortmediumlong_x1d.fits
# 2024-02-21 02:46:20,556 - stpipe.Spec3Pipeline.spectral_leak - INFO - Step spectral_leak done
# 2024-02-21 02:46:20,566 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2024-02-21 02:46:20,567 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# <img style="float: center;" src="https://www.stsci.edu/~dlaw/stsci_logo.png" alt="stsci_logo" width="200px"/>
